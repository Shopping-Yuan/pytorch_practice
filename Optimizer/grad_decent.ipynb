# %%
# %conda install pytorch torchvision torchaudio pytorch-cuda=11.8 -c pytorch -c nvidia
#%conda install numpy
#%conda install pandas
#%conda install -c conda-forge matplotlib
#%conda install -c nvidia cuda-toolkit
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: d:\Anaconda\envs\ML2021_python_3_11_5
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.8
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cuda-command-line-tools-11.8.0|                0           1 KB  nvidia
#     cuda-cudart-11.8.89        |                0         1.4 MB  nvidia
#     cuda-cudart-dev-11.8.89    |                0         723 KB  nvidia
#     cuda-cupti-11.8.87         |                0        11.5 MB  nvidia
#     cuda-libraries-11.8.0      |                0           1 KB  nvidia
#     cuda-libraries-dev-11.8.0  |                0           1 KB  nvidia
#     cuda-memcheck-11.8.86      |                0         183 KB  nvidia
#     cuda-nvrtc-11.8.89         |                0        72.1 MB  nvidia
#     cuda-nvrtc-dev-11.8.89     |                0        16.1 MB  nvidia
#     cuda-nvtx-11.8.86          |                0          43 KB  nvidia
#     cuda-runtime-11.8.0        |                0           1 KB  nvidia
#     cuda-samples-11.5.56       |       h3d39d80_0       237.1 MB  nvidia
#     cuda-toolkit-11.3.0        |       hd997d6f_0           2 KB  nvidia
#     cuda-tools-11.3.0          |       hd997d6f_0           2 KB  nvidia
#     idna-3.4                   |  py311haa95532_0         101 KB
#     libcublas-11.11.3.6        |                0          33 KB  nvidia
#     libcublas-dev-11.11.3.6    |                0       375.9 MB  nvidia
#     libcufft-10.9.0.58         |                0           6 KB  nvidia
#     libcufft-dev-10.9.0.58     |                0       144.6 MB  nvidia
#     libcusolver-11.4.1.48      |                0          29 KB  nvidia
#     libcusolver-dev-11.4.1.48  |                0        94.1 MB  nvidia
#     libcusparse-11.7.5.86      |                0          13 KB  nvidia
#     libcusparse-dev-11.7.5.86  |                0       175.7 MB  nvidia
#     libnpp-11.8.0.86           |                0         294 KB  nvidia
#     libnpp-dev-11.8.0.86       |                0       143.2 MB  nvidia
#     libnvjpeg-11.9.0.86        |                0           4 KB  nvidia
#     libnvjpeg-dev-11.9.0.86    |                0         1.9 MB  nvidia
#     pytorch-2.1.0              |py3.11_cuda11.8_cudnn8_0        1.43 GB  pytorch
#     pytorch-cuda-11.8          |       h24eeafa_5           4 KB  pytorch
#     torchaudio-2.1.0           |      py311_cu118         7.0 MB  pytorch
#     torchvision-0.16.0         |      py311_cu118         8.1 MB  pytorch
#     typing_extensions-4.7.1    |  py311haa95532_0          71 KB
#     ------------------------------------------------------------
#                                            Total:        2.69 GB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      pkgs/main/win-64::brotli-python-1.0.9-py311hd77b12b_7
#   certifi            pkgs/main/win-64::certifi-2023.7.22-py311haa95532_0
#   cffi               pkgs/main/win-64::cffi-1.15.1-py311h2bbff1b_3
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   cryptography       pkgs/main/win-64::cryptography-41.0.3-py311h89fc84f_0
#   cuda-memcheck      nvidia/win-64::cuda-memcheck-11.8.86-0
#   cuda-runtime       nvidia/win-64::cuda-runtime-11.8.0-0
#   cuda-samples       nvidia/win-64::cuda-samples-11.5.56-h3d39d80_0
#   filelock           pkgs/main/win-64::filelock-3.9.0-py311haa95532_0
#   idna               pkgs/main/win-64::idna-3.4-py311haa95532_0
#   jinja2             pkgs/main/win-64::jinja2-3.1.2-py311haa95532_0
#   libjpeg-turbo      pkgs/main/win-64::libjpeg-turbo-2.0.0-h196d8e1_0
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0
#   markupsafe         pkgs/main/win-64::markupsafe-2.1.1-py311h2bbff1b_0
#   mpmath             pkgs/main/win-64::mpmath-1.3.0-py311haa95532_0
#   networkx           pkgs/main/win-64::networkx-3.1-py311haa95532_0
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pyopenssl          pkgs/main/win-64::pyopenssl-23.2.0-py311haa95532_0
#   pysocks            pkgs/main/win-64::pysocks-1.7.1-py311haa95532_0
#   pytorch            pytorch/win-64::pytorch-2.1.0-py3.11_cuda11.8_cudnn8_0
#   pytorch-cuda       pytorch/win-64::pytorch-cuda-11.8-h24eeafa_5
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   pyyaml             pkgs/main/win-64::pyyaml-6.0.1-py311h2bbff1b_0
#   requests           pkgs/main/win-64::requests-2.31.0-py311haa95532_0
#   sympy              pkgs/main/win-64::sympy-1.11.1-py311haa95532_0
#   torchaudio         pytorch/win-64::torchaudio-2.1.0-py311_cu118
#   torchvision        pytorch/win-64::torchvision-0.16.0-py311_cu118
#   typing_extensions  pkgs/main/win-64::typing_extensions-4.7.1-py311haa95532_0
#   urllib3            pkgs/main/win-64::urllib3-1.26.18-py311haa95532_0
#   win_inet_pton      pkgs/main/win-64::win_inet_pton-1.1.0-py311haa95532_0
#   yaml               pkgs/main/win-64::yaml-0.2.5-he774522_0
#
# The following packages will be REMOVED:
#
#   cuda-visual-tools-12.3.0-0
#
# The following packages will be DOWNGRADED:
#
#   cuda-command-line~                               12.3.0-0 --> 11.8.0-0
#   cuda-cudart                                     12.3.52-0 --> 11.8.89-0
#   cuda-cudart-dev                                 12.3.52-0 --> 11.8.89-0
#   cuda-cupti                                      12.3.52-0 --> 11.8.87-0
#   cuda-libraries                                   12.3.0-0 --> 11.8.0-0
#   cuda-libraries-dev                               12.3.0-0 --> 11.8.0-0
#   cuda-nvrtc                                      12.3.52-0 --> 11.8.89-0
#   cuda-nvrtc-dev                                  12.3.52-0 --> 11.8.89-0
#   cuda-nvtx                                       12.3.52-0 --> 11.8.86-0
#   cuda-toolkit                                     12.3.0-0 --> 11.3.0-hd997d6f_0
#   cuda-tools                                       12.3.0-0 --> 11.3.0-hd997d6f_0
#   libcublas                                      12.3.2.9-0 --> 11.11.3.6-0
#   libcublas-dev                                  12.3.2.9-0 --> 11.11.3.6-0
#   libcufft                                     11.0.11.19-0 --> 10.9.0.58-0
#   libcufft-dev                                 11.0.11.19-0 --> 10.9.0.58-0
#   libcusolver                                   11.5.3.52-0 --> 11.4.1.48-0
#   libcusolver-dev                               11.5.3.52-0 --> 11.4.1.48-0
#   libcusparse                                  12.1.3.153-0 --> 11.7.5.86-0
#   libcusparse-dev                              12.1.3.153-0 --> 11.7.5.86-0
#   libnpp                                        12.2.2.32-0 --> 11.8.0.86-0
#   libnpp-dev                                    12.2.2.32-0 --> 11.8.0.86-0
#   libnvjpeg                                     12.2.3.32-0 --> 11.9.0.86-0
#   libnvjpeg-dev                                 12.2.3.32-0 --> 11.9.0.86-0
#
#
#
# Downloading and Extracting Packages
#
# idna-3.4             | 101 KB    |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   |            |   0%
#
#
# libcusparse-11.7.5.8 | 13 KB     |            |   0%
#
#
#
# cuda-cudart-11.8.89  | 1.4 MB    |            |   0%
#
#
#
#
# cuda-runtime-11.8.0  | 1 KB      |            |   0%
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 4 KB      |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     |            |   0%
#
#
#
#
#
#
#
#
# cuda-toolkit-11.3.0  | 2 KB      |            |   0%
#
#
#
#
#
#
#
#
#
# cuda-memcheck-11.8.8 | 183 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-cuda-11.8    | 4 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 29 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 71 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-libraries-11.8. | 1 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-tools-11.3.0    | 2 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-command-line-to | 1 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   |            |   0%
# idna-3.4             | 101 KB    | #5         |  16%
#
#
# libcusparse-11.7.5.8 | 13 KB     | ########## | 100%
#
#
# libcusparse-11.7.5.8 | 13 KB     | ########## | 100%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 1          |   1%
#
#
#
#
# cuda-runtime-11.8.0  | 1 KB      | ########## | 100%
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 4 KB      | ########## | 100%
#
#
#
# cuda-cudart-11.8.89  | 1.4 MB    | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 2          |   2%
#
#
#
# cuda-cudart-11.8.89  | 1.4 MB    | 4          |   4%
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     | ####9      |  49%
# idna-3.4             | 101 KB    | ########## | 100%
# idna-3.4             | 101 KB    | ########## | 100%
#
#
#
#
# cuda-runtime-11.8.0  | 1 KB      | ########## | 100%
#
#
#
#
#
# libnvjpeg-11.9.0.86  | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
# libcublas-11.11.3.6  | 33 KB     | ########## | 100%
#
#
#
# cuda-cudart-11.8.89  | 1.4 MB    | #########8 |  98%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 5          |   5%
#
#
#
#
#
#
#
#
#
# cuda-memcheck-11.8.8 | 183 KB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 6          |   7%
#
#
#
#
#
#
#
#
#
# cuda-memcheck-11.8.8 | 183 KB    | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ##2        |  22%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ####       |  40%
#
#
#
#
#
#
#
#
#
# cuda-memcheck-11.8.8 | 183 KB    | #######    |  70%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 8          |   8%
#
#
#
# cuda-cudart-11.8.89  | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
#
# cuda-toolkit-11.3.0  | 2 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# cuda-memcheck-11.8.8 | 183 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# cuda-memcheck-11.8.8 | 183 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# cuda-toolkit-11.3.0  | 2 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | #####3     |  54%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-cuda-11.8    | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-cuda-11.8    | 4 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ######6    |  66%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 29 KB     | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcusolver-11.4.1.4 | 29 KB     | ########## | 100%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ########4  |  85%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #1         |  11%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #2         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #3         |  13%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #3         |  14%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #4         |  14%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #4         |  14%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 71 KB     | ##2        |  23%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-libraries-11.8. | 1 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-libraries-11.8. | 1 KB      | ########## | 100%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #5         |  16%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #6         |  16%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #6         |  17%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-tools-11.3.0    | 2 KB      | ########## | 100%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   4%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #6         |  17%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-command-line-to | 1 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-command-line-to | 1 KB      | ########## | 100%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #7         |  17%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   4%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   4%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   4%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   4%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #9         |  19%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #9         |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-tools-11.3.0    | 2 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##3        |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 1          |   2%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 71 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 71 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##4        |  25%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   2%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##5        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##7        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##8        |  28%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##9        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 2          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###1       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   3%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###2       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###4       |  34%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###4       |  35%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###5       |  35%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###5       |  36%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###6       |  36%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###6       |  37%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###7       |  38%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###8       |  38%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###8       |  39%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ###9       |  40%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   4%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####       |  40%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####       |  41%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####3      |  43%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####4      |  45%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####5      |  45%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####7      |  47%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   5%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####8      |  49%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 8          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####2     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 5          |   6%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####3     |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####4     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####6     |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |   9%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   7%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #####9     |  60%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   7%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######     |  60%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######1    |  61%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######2    |  62%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######2    |  63%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######3    |  63%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######4    |  64%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   7%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######5    |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   |            |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######8    |  68%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######8    |  69%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ######9    |  69%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######1   |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######2   |  72%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   8%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   8%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   9%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######6   |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######6   |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######8   |  79%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #######9   |  79%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########   |  80%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########   |  81%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########1  |  82%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########2  |  83%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########3  |  83%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########4  |  84%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########4  |  85%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########5  |  86%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########6  |  87%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########7  |  87%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | 9          |  10%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########8  |  88%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########8  |  89%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########  |  91%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  10%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########4 |  95%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########5 |  95%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########6 |  96%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #          |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########7 |  97%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  11%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  11%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  11%
#
# cuda-nvrtc-dev-11.8. | 16.1 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #1         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #2         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #2         |  12%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcufft-dev-10.9.0. | 144.6 MB  | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | 1          |   1%
#
#
#
#
#
#
# libcusparse-dev-11.7 | 175.7 MB  | #3         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  93%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########3 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  96%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.0        | 1.43 GB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
import torch
import pandas
import numpy

# %%
# %conda env list
# Out:
# # conda environments:
# #
# base                     D:\Anaconda
# ML2021_python_3_11_5  *  D:\Anaconda\envs\ML2021_python_3_11_5
# ML2021_python_3_11_5     d:\Anaconda\envs\ML2021_python_3_11_5
#
#
# Note: you may need to restart the kernel to use updated packages.
