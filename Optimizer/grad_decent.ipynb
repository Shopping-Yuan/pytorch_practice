# %%
# %conda install pytorch
#%conda install numpy
#%conda install pandas
#%conda install -c conda-forge matplotlib
#%conda install -c nvidia cuda-toolkit
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: d:\Anaconda\envs\ML2021_python_3_11_5
#
#   added / updated specs:
#     - pytorch
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cffi-1.15.1                |  py311h2bbff1b_3         276 KB
#     jinja2-3.1.2               |  py311haa95532_0         290 KB
#     markupsafe-2.1.1           |  py311h2bbff1b_0          27 KB
#     ninja-1.10.2               |       haa95532_5          14 KB
#     ninja-base-1.10.2          |       h6d14046_5         255 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     pytorch-2.0.1              |cpu_py311hd080823_0        91.2 MB
#     ------------------------------------------------------------
#                                            Total:        92.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   cffi               pkgs/main/win-64::cffi-1.15.1-py311h2bbff1b_3
#   filelock           pkgs/main/win-64::filelock-3.9.0-py311haa95532_0
#   jinja2             pkgs/main/win-64::jinja2-3.1.2-py311haa95532_0
#   libuv              pkgs/main/win-64::libuv-1.44.2-h2bbff1b_0
#   markupsafe         pkgs/main/win-64::markupsafe-2.1.1-py311h2bbff1b_0
#   mpmath             pkgs/main/win-64::mpmath-1.3.0-py311haa95532_0
#   networkx           pkgs/main/win-64::networkx-3.1-py311haa95532_0
#   ninja              pkgs/main/win-64::ninja-1.10.2-haa95532_5
#   ninja-base         pkgs/main/win-64::ninja-base-1.10.2-h6d14046_5
#   pycparser          pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0
#   pytorch            pkgs/main/win-64::pytorch-2.0.1-cpu_py311hd080823_0
#   sympy              pkgs/main/win-64::sympy-1.11.1-py311haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# pycparser-2.21       | 94 KB     |            |   0%
#
# markupsafe-2.1.1     | 27 KB     |            |   0%
#
#
# pytorch-2.0.1        | 91.2 MB   |            |   0%
#
#
#
# cffi-1.15.1          | 276 KB    |            |   0%
#
#
#
#
# jinja2-3.1.2         | 290 KB    |            |   0%
#
#
#
#
#
# ninja-base-1.10.2    | 255 KB    |            |   0%
#
#
#
#
#
#
# ninja-1.10.2         | 14 KB     |            |   0%
#
# markupsafe-2.1.1     | 27 KB     | #####9     |  60%
#
#
#
#
# jinja2-3.1.2         | 290 KB    | 5          |   6%
#
#
# pytorch-2.0.1        | 91.2 MB   |            |   0%
#
#
#
#
#
# ninja-base-1.10.2    | 255 KB    | 6          |   6%
# pycparser-2.21       | 94 KB     | #6         |  17%
#
#
#
# cffi-1.15.1          | 276 KB    | 5          |   6%
#
#
# pytorch-2.0.1        | 91.2 MB   |            |   0%
#
#
#
#
# jinja2-3.1.2         | 290 KB    | ######6    |  66%
#
#
#
# cffi-1.15.1          | 276 KB    | ####       |  41%
# pycparser-2.21       | 94 KB     | ######7    |  68%
#
#
#
#
#
# ninja-base-1.10.2    | 255 KB    | ##5        |  25%
#
#
#
#
# jinja2-3.1.2         | 290 KB    | #########3 |  94%
#
#
# pytorch-2.0.1        | 91.2 MB   |            |   0%
#
#
#
#
#
#
# ninja-1.10.2         | 14 KB     | ########## | 100%
#
#
# pytorch-2.0.1        | 91.2 MB   | 1          |   1%
#
# markupsafe-2.1.1     | 27 KB     | ########## | 100%
#
# markupsafe-2.1.1     | 27 KB     | ########## | 100%
# pycparser-2.21       | 94 KB     | ########## | 100%
# pycparser-2.21       | 94 KB     | ########## | 100%
#
#
#
#
#
# ninja-base-1.10.2    | 255 KB    | ########## | 100%
#
#
#
#
#
# ninja-base-1.10.2    | 255 KB    | ########## | 100%
#
#
# pytorch-2.0.1        | 91.2 MB   | 1          |   2%
#
#
#
#
#
#
# ninja-1.10.2         | 14 KB     | ########## | 100%
#
#
#
#
# jinja2-3.1.2         | 290 KB    | ########## | 100%
#
#
# pytorch-2.0.1        | 91.2 MB   | 2          |   3%
#
#
#
# cffi-1.15.1          | 276 KB    | ########## | 100%
#
#
#
# cffi-1.15.1          | 276 KB    | ########## | 100%
#
#
# pytorch-2.0.1        | 91.2 MB   | 3          |   3%
#
#
# pytorch-2.0.1        | 91.2 MB   | 3          |   4%
#
#
# pytorch-2.0.1        | 91.2 MB   | 4          |   4%
#
#
# pytorch-2.0.1        | 91.2 MB   | 5          |   5%
#
#
# pytorch-2.0.1        | 91.2 MB   | 5          |   6%
#
#
# pytorch-2.0.1        | 91.2 MB   | 6          |   6%
#
#
# pytorch-2.0.1        | 91.2 MB   | 6          |   7%
#
#
# pytorch-2.0.1        | 91.2 MB   | 7          |   7%
#
#
# pytorch-2.0.1        | 91.2 MB   | 8          |   8%
#
#
# pytorch-2.0.1        | 91.2 MB   | 8          |   9%
#
#
# pytorch-2.0.1        | 91.2 MB   | 9          |   9%
#
#
# pytorch-2.0.1        | 91.2 MB   | 9          |  10%
#
#
# pytorch-2.0.1        | 91.2 MB   | #          |  10%
#
#
# pytorch-2.0.1        | 91.2 MB   | #          |  11%
#
#
# pytorch-2.0.1        | 91.2 MB   | #1         |  12%
#
#
# pytorch-2.0.1        | 91.2 MB   | #2         |  12%
#
#
# pytorch-2.0.1        | 91.2 MB   | #2         |  13%
#
#
# pytorch-2.0.1        | 91.2 MB   | #3         |  13%
#
#
# pytorch-2.0.1        | 91.2 MB   | #3         |  14%
#
#
# pytorch-2.0.1        | 91.2 MB   | #4         |  15%
#
#
# pytorch-2.0.1        | 91.2 MB   | #5         |  15%
#
#
# pytorch-2.0.1        | 91.2 MB   | #5         |  16%
#
#
# pytorch-2.0.1        | 91.2 MB   | #6         |  16%
#
#
# pytorch-2.0.1        | 91.2 MB   | #6         |  17%
#
#
# pytorch-2.0.1        | 91.2 MB   | #7         |  17%
#
#
# pytorch-2.0.1        | 91.2 MB   | #7         |  18%
#
#
# pytorch-2.0.1        | 91.2 MB   | #8         |  18%
#
#
# pytorch-2.0.1        | 91.2 MB   | #9         |  19%
#
#
# pytorch-2.0.1        | 91.2 MB   | #9         |  20%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##         |  20%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##         |  21%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##1        |  21%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##2        |  22%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##2        |  23%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##3        |  23%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##3        |  24%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##4        |  24%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##4        |  25%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##5        |  26%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##6        |  26%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##6        |  27%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##7        |  27%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##7        |  28%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##8        |  28%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##8        |  29%
#
#
# pytorch-2.0.1        | 91.2 MB   | ##9        |  29%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###        |  30%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###        |  31%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###1       |  31%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###1       |  32%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###2       |  32%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###2       |  33%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###3       |  34%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###4       |  34%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###4       |  35%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###5       |  35%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###5       |  36%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###6       |  36%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###7       |  37%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###7       |  38%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###8       |  38%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###8       |  39%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###9       |  39%
#
#
# pytorch-2.0.1        | 91.2 MB   | ###9       |  40%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####       |  41%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####1      |  41%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####1      |  42%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####2      |  42%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####3      |  43%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####3      |  44%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####4      |  44%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####4      |  45%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####5      |  45%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####5      |  46%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####6      |  47%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####7      |  47%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####7      |  48%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####8      |  48%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####9      |  49%
#
#
# pytorch-2.0.1        | 91.2 MB   | ####9      |  50%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####      |  50%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####      |  51%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####1     |  52%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####2     |  52%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####2     |  53%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####3     |  53%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####3     |  54%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####4     |  54%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####4     |  55%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####5     |  55%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####5     |  56%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####6     |  56%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####6     |  57%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####7     |  57%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####7     |  58%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####8     |  58%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####8     |  59%
#
#
# pytorch-2.0.1        | 91.2 MB   | #####9     |  59%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######     |  60%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######     |  61%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######1    |  61%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######1    |  62%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######2    |  62%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######2    |  63%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######3    |  64%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######4    |  64%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######4    |  65%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######5    |  65%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######6    |  66%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######6    |  67%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######7    |  67%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######7    |  68%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######8    |  68%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######9    |  69%
#
#
# pytorch-2.0.1        | 91.2 MB   | ######9    |  70%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######    |  70%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######    |  71%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######1   |  71%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######1   |  72%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######2   |  73%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######3   |  73%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######3   |  74%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######4   |  74%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######5   |  75%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######5   |  76%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######6   |  76%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######6   |  77%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######7   |  77%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######7   |  78%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######8   |  79%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######9   |  79%
#
#
# pytorch-2.0.1        | 91.2 MB   | #######9   |  80%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########   |  80%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########   |  81%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########1  |  82%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########2  |  82%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########2  |  83%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########3  |  83%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########3  |  84%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########4  |  85%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########5  |  85%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########5  |  86%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########6  |  86%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########7  |  87%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########7  |  88%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########8  |  88%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########8  |  89%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########9  |  90%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########  |  90%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########  |  91%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########1 |  91%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########2 |  92%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########2 |  93%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########3 |  93%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########3 |  94%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########4 |  95%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########5 |  95%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########5 |  96%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########6 |  96%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########6 |  97%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########7 |  98%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########8 |  98%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########8 |  99%
#
#
# pytorch-2.0.1        | 91.2 MB   | #########9 |  99%
#
#
# pytorch-2.0.1        | 91.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0

# %%
import torch
import pandas
import numpy

# %%
# %conda env list
# Out:
# # conda environments:
# #
# base                     D:\Anaconda
# ML2021_python_3_11_5  *  D:\Anaconda\envs\ML2021_python_3_11_5
# ML2021_python_3_11_5     d:\Anaconda\envs\ML2021_python_3_11_5
#
#
# Note: you may need to restart the kernel to use updated packages.
